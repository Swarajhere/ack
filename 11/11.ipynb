# %%
import pandas as pd

df = pd.read_csv('movies_metadata.csv')

df.head()
# Out:
# C:\Users\Mtronics Computers\AppData\Local\Temp\ipykernel_16336\2931266142.py:3: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('movies_metadata.csv')
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
# ...

# %%
print(df['original_language'].unique())
# Out:
# ['en' 'fr' 'zh' 'it' 'fa' 'nl' 'de' 'cn' 'ar' 'es' 'ru' 'sv' 'ja' 'ko'
#  'sr' 'bn' 'he' 'pt' 'wo' 'ro' 'hu' 'cy' 'vi' 'cs' 'da' 'no' 'nb' 'pl'
#  'el' 'sh' 'xx' 'mk' 'bo' 'ca' 'fi' 'th' 'sk' 'bs' 'hi' 'tr' 'is' 'ps'
#  'ab' 'eo' 'ka' 'mn' 'bm' 'zu' 'uk' 'af' 'la' 'et' 'ku' 'fy' 'lv' 'ta'
#  'sl' 'tl' 'ur' 'rw' 'id' 'bg' 'mr' 'lt' 'kk' 'ms' 'sq' nan '104.0' 'qu'
#  'te' 'am' 'jv' 'tg' 'ml' 'hr' 'lo' 'ay' 'kn' 'eu' 'ne' 'pa' 'ky' 'gl'
#  '68.0' 'uz' 'sm' 'mt' '82.0' 'hy' 'iu' 'lb' 'si']

# %%
# m. Create data subsets for different languages
subset_en = df[df['original_language'] == 'en']
subset_fr = df[df['original_language'] == 'fr']

# %%
subset_en.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
# n. Merge two subsets (e.g., English and French movies)
merged_df = pd.concat([subset_en, subset_fr])

# %%
# o. Sort Data using customer ratings (vote_average)
sorted_df = df.sort_values(by='vote_average', ascending=False)

# %%
sorted_df.head()
# Out:
#        adult                              belongs_to_collection budget  \
# 31082  False                                                NaN    200
# 45371  False  {'id': 477208, 'name': 'DC Super Hero Girls Co...      0
# 21798  False                                                NaN      0
# 23851  False                                                NaN      0
# 35999  False                                                NaN      0
#
#                                                   genres homepage      id  \
# 31082  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...      NaN  249677
# 45371                  [{'id': 16, 'name': 'Animation'}]      NaN  460135
# 21798                [{'id': 99, 'name': 'Documentary'}]      NaN  113364
# 23851                [{'id': 99, 'name': 'Documentary'}]      NaN  261813
# 35999  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN  211139
#
#          imdb_id original_language                         original_title  \
# ...

# %%
# p. Transposing Data
transposed_df = df.transpose()
transposed_df.head()
# Out:
#                                                                    0      \
# adult                                                              False
# belongs_to_collection  {'id': 10194, 'name': 'Toy Story Collection', ...
# budget                                                          30000000
# genres                 [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# homepage                            http://toystory.disney.com/toy-story
#
#                                                                    1      \
# adult                                                              False
# belongs_to_collection                                                NaN
# budget                                                          65000000
# genres                 [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# homepage                                                             NaN
#
#                                                                    2      \
# ...

# %%
# q. Melting Data to long format (select a few columns)
melted_df = pd.melt(
    df,
    id_vars=['id', 'original_language'],
    value_vars=['budget', 'revenue', 'runtime', 'vote_average'],
    var_name='Feature',
    value_name='Value'
)

melted_df.head()
# Out:
#       id original_language Feature     Value
# 0    862                en  budget  30000000
# 1   8844                en  budget  65000000
# 2  15602                en  budget         0
# 3  31357                en  budget  16000000
# 4  11862                en  budget         0

# %%
# Convert the 'Value' column to numeric, coercing errors if necessary
melted_df['Value'] = pd.to_numeric(melted_df['Value'], errors='coerce')

# r. Casting data back to wide format
wide_df = melted_df.pivot_table(
    index=['id', 'original_language'],
    columns='Feature',
    values='Value'
).reset_index()

wide_df.head()
# Out:
# Feature      id original_language     budget    revenue  runtime  vote_average
# 0           100                en  1350000.0  3897569.0    105.0           7.5
# 1         10000                es        0.0        0.0    116.0           7.2
# 2         10001                en        0.0        0.0     91.0           4.5
# 3        100010                en        0.0        0.0    116.0           6.0
# 4        100017                de        0.0        0.0     87.0           4.8
